# %%
import json
from mentions.visualizer import display_mentions, highlight_mentions_in_text

doc_ir = json.load(open("outputs_ir/DOC-068C46038B6B.json", "r", encoding="utf-8"))
mentions = json.load(open("outputs_mentions/DOC-068C46038B6B_mentions.json", "r", encoding="utf-8"))

display_mentions(mentions)
highlight_mentions_in_text(doc_ir, mentions["mentions"])
# Out:
# <div style='font-family:Segoe UI, sans-serif; line-height:1.8em;'><h4 style='margin-bottom:0.5em;'>📄 Menciones extraídas:</h4>
#         <span style="
#             background-color:#9e9e9e;
#             border-radius:6px;
#             padding:2px 6px;
#             margin:2px;
#             display:inline-block;
#             color:white;
#             font-size:14px;
#             font-weight:600;"
#             title="Dominio: generic">
#             OpenAI <span style="font-size:11px; opacity:0.8;">ORGANIZATION</span>
#         </span>
#
#         <span style="
#             background-color:#9e9e9e;
#             border-radius:6px;
#             padding:2px 6px;
#             margin:2px;
#             display:inline-block;
#             color:white;
#             font-size:14px;
#             font-weight:600;"
#             title="Dominio: generic">
#             ChatGPT <span style="font-size:11px; opacity:0.8;">PRODUCT</span>
#         </span>
#
#         <span style="
# ...
