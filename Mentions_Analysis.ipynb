# %%
import json
from mentions.visualizer import display_mentions, highlight_mentions_in_text

doc_ir = json.load(open("outputs_ir/DOC-5755EFEA-512F.json", "r", encoding="utf-8"))
mentions = json.load(open("outputs_mentions/DOC-5755EFEA-512F_mentions.json", "r", encoding="utf-8"))

display_mentions(mentions)
highlight_mentions_in_text(doc_ir, mentions["mentions"])
# Out:
# <div style='font-family:Segoe UI, sans-serif; line-height:1.8em;'><div style='margin-bottom:8px;'><b>🎨 Leyenda de colores (por dominio):</b><br>
#         <span style="
#             background-color:#f4b400;
#             border-radius:6px;
#             padding:2px 6px;
#             margin:3px;
#             display:inline-block;
#             color:white;
#             font-weight:600;
#             font-size:13px;">
#             legal
#         </span>
#
#         <span style="
#             background-color:#0f9d58;
#             border-radius:6px;
#             padding:2px 6px;
#             margin:3px;
#             display:inline-block;
#             color:white;
#             font-weight:600;
#             font-size:13px;">
#             financial
#         </span>
#
#         <span style="
#             background-color:#db4437;
#             border-radius:6px;
#             padding:2px 6px;
#             margin:3px;
#             display:inline-block;
# ...
