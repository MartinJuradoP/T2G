# %%
import json
from mentions.visualizer import display_mentions, highlight_mentions_in_text

doc_ir = json.load(open("outputs_ir/DOC-8680C78E2D93.json", "r", encoding="utf-8"))
mentions = json.load(open("outputs_mentions/DOC-8680C78E2D93_mentions.json", "r", encoding="utf-8"))

display_mentions(mentions)
highlight_mentions_in_text(doc_ir, mentions["mentions"])
# Out:
# <div style='font-family:Segoe UI, sans-serif; line-height:1.8em;'><h4 style='margin-bottom:0.5em;'>📄 Menciones extraídas:</h4>
#         <span style="
#             background-color:#9e9e9e;
#             border-radius:6px;
#             padding:2px 6px;
#             margin:2px;
#             display:inline-block;
#             color:white;
#             font-size:14px;
#             font-weight:600;"
#             title="Dominio: generic">
#             Abraham Lincoln <span style="font-size:11px; opacity:0.8;">PERSON</span>
#         </span>
#
#         <span style="
#             background-color:#9e9e9e;
#             border-radius:6px;
#             padding:2px 6px;
#             margin:2px;
#             display:inline-block;
#             color:white;
#             font-size:14px;
#             font-weight:600;"
#             title="Dominio: generic">
#             February <span style="font-size:11px; opacity:0.8;">DATE</span>
#         </span>
#
#         <span style="
# ...
